# %%
import numpy as np
import pandas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
os.chdir("C:\\Users\\Madhu Gupta\\Downloads\\Project\\bank+marketing")

# %%
data = pd.read_csv("C:\\Users\\Madhu Gupta\\Downloads\\Project\\bank+marketing\\bank-additional\\bank-additional\\bank-additional-full.csv",delimiter=';')
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
data.rename(columns={'y':'deposit'}, inplace=True)
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
data.shape
# Out:
# (41188, 21)

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 12

# %%
data.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 12

# %%
data_obj= data.select_dtypes(include='object').columns

data_num= data.select_dtypes(exclude='object').columns

# %%
for feature in data_num:
    sns.histplot(x=feature,data=data,bins=25,kde=True,color='#0000ff')
    plt.title('Visualizing numerical columns using histogram')
    plt.show()
    
#Numerical Visualization

# %%
for feature in data_obj:
    plt.figure(figsize=(10,6))
    plt.title(f"Count plot of {feature}")
    sns.countplot(x=feature,data=data,palette='viridis')
    plt.xticks(rotation=40)
    plt.show()
    
#Category Visualization

# %%
data.plot(kind='box', subplots=True, layout=(5,2), figsize=(10,30))
plt.show()

# %%
columns = ['age', 'campaign', 'duration']

for column in columns:
    q1 = np.percentile(data[column], 25)
    q3 = np.percentile(data[column], 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    # Filter the DataFrame for the current column
    data = data[(data[column] >= lower_bound) & (data[column] <= upper_bound)]

# %%
data.plot(kind='box', subplots=True, layout=(5,2), figsize=(10,30))
plt.show()

# %%
# Select only the numerical columns
numerical_data = data.select_dtypes(include=[np.number])

# Create the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numerical_data.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
high_corr_cols = ['emp.var.rate','euribor3m','nr.employed']

# %%
# copy the original dataframe

data1=data.copy()

# Removing high correlated columns from the dataset
data1.drop(high_corr_cols, inplace=True, axis=1)
data1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'cons.price.idx', 'cons.conf.idx', 'y'],
#       dtype='object')

# %%
data1.shape
# Out:
# (35550, 18)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data_encoded = data1.apply(le.fit_transform)
data_encoded
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       39    3        1          0        0        0     0        1      6
# 1       40    7        1          3        1        0     0        1      6
# 2       20    7        1          3        0        2     0        1      6
# 3       23    0        1          1        0        0     0        1      6
# 4       39    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41181   20    0        1          6        0        2     0        0      7
# 41182   12   10        2          0        0        2     0        0      7
# 41184   29    1        1          5        0        0     0        0      7
# 41185   39    5        1          6        0        2     0        0      7
# 41186   27    9        1          5        0        0     0        0      7
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()
data['deposit'] = labelEncoder.fit_transform(data['deposit'])
data['marital'] = labelEncoder.fit_transform(data['marital'])
data['education'] = labelEncoder.fit_transform(data['education'])
data['default'] = labelEncoder.fit_transform(data['default'])
data['housing'] = labelEncoder.fit_transform(data['housing'])
data['loan'] = labelEncoder.fit_transform(data['loan'])
data['poutcome'] = labelEncoder.fit_transform(data['poutcome'])

# %%
data["month"].value_counts().sort_values(ascending = False).head(20)
# Out:
# may    12166
# jul     5882
# aug     5316
# jun     4508
# nov     3708
# apr     2311
# oct      594
# mar      467
# sep      459
# dec      139
# Name: month, dtype: int64

# %%
data["job"].value_counts().sort_values(ascending = False).head(20)
# Out:
# admin.           9107
# blue-collar      8077
# technician       5888
# services         3454
# management       2551
# entrepreneur     1270
# self-employed    1222
# retired          1136
# housemaid         899
# unemployed        887
# student           780
# unknown           279
# Name: job, dtype: int64

# %%
# Get whole set of dummy variables for all categorical columns
def one_hot_encode_top(data, col, top_6_labels):
    for label in top_6_labels:
        data[col+'_'+label] = np.where(data[col] == label,1,0)
data_new = pd.read_csv("C:\\Users\\Madhu Gupta\\Downloads\\Project\\bank+marketing\\bank\\bank.csv",delimiter=';')
data_new.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
top_6_labels = [x for x in data["job"].value_counts().sort_values(ascending = False).head(6).index]
one_hot_encode_top(data, "job", top_6_labels)
data.head()
# Out:
#    age        job  marital  education  default  housing  loan    contact  \
# 0   56  housemaid        1          0        0        0     0  telephone
# 1   57   services        1          3        1        0     0  telephone
# 2   37   services        1          3        0        2     0  telephone
# 3   40     admin.        1          1        0        0     0  telephone
# 4   56   services        1          3        0        0     2  telephone
#
#   month day_of_week  ...  cons.conf.idx  euribor3m  nr.employed  deposit  \
# 0   may         mon  ...          -36.4      4.857       5191.0        0
# 1   may         mon  ...          -36.4      4.857       5191.0        0
# 2   may         mon  ...          -36.4      4.857       5191.0        0
# 3   may         mon  ...          -36.4      4.857       5191.0        0
# 4   may         mon  ...          -36.4      4.857       5191.0        0
#
#    job_admin.  job_blue-collar  job_technician  job_services  job_management  \
# ...

# %%
# Encode for month column
top_6_labels = [x for x in data["month"].value_counts().sort_values(ascending = False).head(6).index]
one_hot_encode_top(data, "month", top_6_labels)
data.head()
# Out:
#    age        job  marital  education  default  housing  loan    contact  \
# 0   56  housemaid        1          0        0        0     0  telephone
# 1   57   services        1          3        1        0     0  telephone
# 2   37   services        1          3        0        2     0  telephone
# 3   40     admin.        1          1        0        0     0  telephone
# 4   56   services        1          3        0        0     2  telephone
#
#   month day_of_week  ...  job_technician  job_services  job_management  \
# 0   may         mon  ...               0             0               0
# 1   may         mon  ...               0             1               0
# 2   may         mon  ...               0             1               0
# 3   may         mon  ...               0             0               0
# 4   may         mon  ...               0             1               0
#
#    job_entrepreneur  month_may  month_jul  month_aug  month_jun  month_nov  \
# ...

# %%
# Drop initial job and month categorical column
data.drop(columns = ["job", "month"], axis =1, inplace = True)
data.head()
# Out:
#    age  marital  education  default  housing  loan    contact day_of_week  \
# 0   56        1          0        0        0     0  telephone         mon
# 1   57        1          3        1        0     0  telephone         mon
# 2   37        1          3        0        2     0  telephone         mon
# 3   40        1          1        0        0     0  telephone         mon
# 4   56        1          3        0        0     2  telephone         mon
#
#    duration  campaign  ...  job_technician  job_services  job_management  \
# 0       261         1  ...               0             0               0
# 1       149         1  ...               0             1               0
# 2       226         1  ...               0             1               0
# 3       151         1  ...               0             0               0
# 4       307         1  ...               0             1               0
#
#    job_entrepreneur  month_may  month_jul  month_aug  month_jun  month_nov  \
# ...

# %%
data = data[["age", "campaign", "duration", "pdays", "previous", "marital", "education", 
             "default", "housing", "loan", "poutcome", "job_management", "job_blue-collar", "job_technician",
             "job_admin.", "job_services", "month_may", "month_aug", "month_jul", "month_jun", "month_nov",
             "month_apr", "deposit"]]

# %%
x = data.iloc[:, :25]
y = data.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25,random_state=1)
print("X_train: ", x_train.shape)
print("X_test: ", x_test.shape)
print("y_train: ", y_train.shape)
print("y_test: ", y_test.shape)
# Out:
# X_train:  (26662, 23)
# X_test:  (8888, 23)
# y_train:  (26662,)
# y_test:  (8888,)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

def eval_model(y_test,y_pred):
    acc = accuracy_score(y_test,y_pred)
    print('Accuracy_Score',acc)
    cm = confusion_matrix(y_test,y_pred)
    print('Confusion Matrix\n',cm)
    print('Classification Report\n',classification_report(y_test,y_pred))

def mscore(model):
    train_score = model.score(x_train,y_train)
    test_score = model.score(x_test,y_test)
    print('Training Score',train_score)  
    print('Testing Score',test_score)

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(criterion='gini',max_depth=5,min_samples_split=10)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=10)

# %%
mscore(dt)
# Out:
# Training Score 1.0
# Testing Score 1.0

# %%
ypred_dt = dt.predict(x_test)
print(ypred_dt)
# Out:
# [0 0 0 ... 0 0 0]

# %%
eval_model(y_test,ypred_dt)
# Out:
# Accuracy_Score 1.0
# Confusion Matrix
#  [[8155    0]
#  [   0  733]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8155
#            1       1.00      1.00      1.00       733
#
#     accuracy                           1.00      8888
#    macro avg       1.00      1.00      1.00      8888
# weighted avg       1.00      1.00      1.00      8888

# %%
cn = ['no','yes']
fn = x_train.columns
print(fn)
print(cn)
# Out:
# Index(['age', 'campaign', 'duration', 'pdays', 'previous', 'marital',
#        'education', 'default', 'housing', 'loan', 'poutcome', 'job_management',
#        'job_blue-collar', 'job_technician', 'job_admin.', 'job_services',
#        'month_may', 'month_aug', 'month_jul', 'month_jun', 'month_nov',
#        'month_apr', 'deposit'],
#       dtype='object')
# ['no', 'yes']

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(30,10))
plot_tree(dt,class_names=cn,filled=True)
plt.show()

# %%
dt1 = DecisionTreeClassifier(criterion='entropy',max_depth=4,min_samples_split=15)
dt1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_split=15)

# %%
mscore(dt1)
# Out:
# Training Score 1.0
# Testing Score 1.0

# %%
ypred_dt1 = dt1.predict(x_test)

# %%
eval_model(y_test,ypred_dt1)
# Out:
# Accuracy_Score 1.0
# Confusion Matrix
#  [[8155    0]
#  [   0  733]]
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8155
#            1       1.00      1.00      1.00       733
#
#     accuracy                           1.00      8888
#    macro avg       1.00      1.00      1.00      8888
# weighted avg       1.00      1.00      1.00      8888

# %%
plt.figure(figsize=(40,20))
plot_tree(dt1,class_names=cn,filled=True)
plt.show()
